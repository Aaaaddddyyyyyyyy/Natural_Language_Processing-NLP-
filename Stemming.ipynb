# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaaaddddyyyyyyyy/Natural_Language_Processing-NLP-/blob/main/Stemming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps=PorterStemmer()
def stem_words(text):
  return" ".join([ps.stem(word) for word in text.split()])

# %%
sample='walk walks walking walked'
stem_words(sample)
# Out:
# 'walk walk walk walk'

# %%
text='She connected the devices and checked the connection.students are studying hard for their exams.'
stem_words(text)
# Out:
# 'she connect the devic and check the connection.stud are studi hard for their exams.'
